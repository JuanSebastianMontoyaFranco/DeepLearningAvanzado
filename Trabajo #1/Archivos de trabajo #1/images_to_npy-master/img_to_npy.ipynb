# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/deep_learning_avanzado/images_to_npy-master
# !pwd
# !ls
# Out:
# /content/drive/MyDrive/deep_learning_avanzado/images_to_npy-master
# /content/drive/MyDrive/deep_learning_avanzado/images_to_npy-master
# image_dir  img_to_npy.ipynb  img_to_npy.py  README.md  test.py	val.txt

# %%
import tensorflow as tf

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# !python img_to_npy.py --input_height=224 --input_width=224 --classes=4
# Out:
# -------------------------------------
# 3.10.11 (main, Apr  5 2023, 14:15:10) [GCC 9.4.0]
# -------------------------------------
#  Command line options:
# --image_dir     :  image_dir
# --label_file    :  val.txt
# --classes       :  4
# --input_height  :  224
# --input_width   :  224
# --input_chans   :  3
# --resize        :  False
# --normalize     :  False
# --one_hot       :  False
# --compress      :  False
# --output_file   :  dataset.npz
# -------------------------------------
#  x shape: (1200, 224, 224, 3)
#  x data type: uint8
#  y shape: (1200,)
#  y data type: uint8
#  Saved to dataset.npz

# %%
import numpy as np
train_data = np.load('dataset.npz')
print(train_data.files)
x_train = train_data['x']
y_train = train_data['y']
# Out:
# ['x', 'y']

# %%
print(x_train.shape) 
print(y_train.shape)
# Out:
# (1200, 224, 224, 3)
# (1200,)

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[300])
